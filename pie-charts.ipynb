# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"countypres_2000-2024.csv")

# %%
df
# Out:
#        year    state state_po county_name  county_fips        office  \
# 0      2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 1      2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 2      2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 3      2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 4      2000  ALABAMA       AL     BALDWIN       1003.0  US PRESIDENT
# ...     ...      ...      ...         ...          ...           ...
# 94404  2024  WYOMING       WY      WESTON      56045.0  US PRESIDENT
# 94405  2024  WYOMING       WY      WESTON      56045.0  US PRESIDENT
# 94406  2024  WYOMING       WY      WESTON      56045.0  US PRESIDENT
# 94407  2024  WYOMING       WY      WESTON      56045.0  US PRESIDENT
# 94408  2024  WYOMING       WY      WESTON      56045.0  US PRESIDENT
#
#              candidate       party  candidatevotes  totalvotes   version  \
# 0              AL GORE    DEMOCRAT            4942       17208  20250821
# 1       GEORGE W. BUSH  REPUBLICAN           11993       17208  20250821
# 2                OTHER       OTHER             113       17208  20250821
# 3          RALPH NADER       GREEN             160       17208  20250821
# 4              AL GORE    DEMOCRAT           13997       56480  20250821
# ...                ...         ...             ...         ...       ...
# 94404   DONALD J TRUMP  REPUBLICAN            3069        3512  20250821
# 94405  KAMALA D HARRIS    DEMOCRAT             378        3512  20250821
# 94406            OTHER       OTHER              18        3512  20250821
# 94407        OVERVOTES         NaN               1        3512  20250821
# 94408       UNDERVOTES         NaN              20        3512  20250821
#
#         mode
# 0      TOTAL
# 1      TOTAL
# 2      TOTAL
# 3      TOTAL
# 4      TOTAL
# ...      ...
# 94404    NaN
# 94405    NaN
# 94406    NaN
# 94407    NaN
# 94408    NaN
#
# [94409 rows x 12 columns]

# %%
df2 = df.copy()

# %%
df2 = df2.drop(columns = ['office', 'state'])

# %%
df2
# Out:
#        year state_po county_name  county_fips        candidate       party  \
# 0      2000       AL     AUTAUGA       1001.0          AL GORE    DEMOCRAT
# 1      2000       AL     AUTAUGA       1001.0   GEORGE W. BUSH  REPUBLICAN
# 2      2000       AL     AUTAUGA       1001.0            OTHER       OTHER
# 3      2000       AL     AUTAUGA       1001.0      RALPH NADER       GREEN
# 4      2000       AL     BALDWIN       1003.0          AL GORE    DEMOCRAT
# ...     ...      ...         ...          ...              ...         ...
# 94404  2024       WY      WESTON      56045.0   DONALD J TRUMP  REPUBLICAN
# 94405  2024       WY      WESTON      56045.0  KAMALA D HARRIS    DEMOCRAT
# 94406  2024       WY      WESTON      56045.0            OTHER       OTHER
# 94407  2024       WY      WESTON      56045.0        OVERVOTES         NaN
# 94408  2024       WY      WESTON      56045.0       UNDERVOTES         NaN
#
#        candidatevotes  totalvotes   version   mode
# 0                4942       17208  20250821  TOTAL
# 1               11993       17208  20250821  TOTAL
# 2                 113       17208  20250821  TOTAL
# 3                 160       17208  20250821  TOTAL
# 4               13997       56480  20250821  TOTAL
# ...               ...         ...       ...    ...
# 94404            3069        3512  20250821    NaN
# 94405             378        3512  20250821    NaN
# 94406              18        3512  20250821    NaN
# 94407               1        3512  20250821    NaN
# 94408              20        3512  20250821    NaN
#
# [94409 rows x 10 columns]

# %%
x = df2.groupby(['year', 'state_po', 'county_name', 'candidate', 'party'])['candidatevotes'].sum()
x = x.reset_index()
y = pd.DataFrame(x)

# %%
y['result'] = ' '
y
# Out:
#        year state_po  county_name        candidate        party  \
# 0      2000       AK   DISTRICT 1          AL GORE     DEMOCRAT
# 1      2000       AK   DISTRICT 1   GEORGE W. BUSH   REPUBLICAN
# 2      2000       AK   DISTRICT 1            OTHER        OTHER
# 3      2000       AK   DISTRICT 1      RALPH NADER        GREEN
# 4      2000       AK  DISTRICT 10          AL GORE     DEMOCRAT
# ...     ...      ...          ...              ...          ...
# 76973  2024       WY     WASHAKIE            OTHER        OTHER
# 76974  2024       WY       WESTON     CHASE OLIVER  LIBERTARIAN
# 76975  2024       WY       WESTON   DONALD J TRUMP   REPUBLICAN
# 76976  2024       WY       WESTON  KAMALA D HARRIS     DEMOCRAT
# 76977  2024       WY       WESTON            OTHER        OTHER
#
#        candidatevotes result
# 0                1284
# 1                4681
# 2                 216
# 3                 475
# 4                2194
# ...               ...    ...
# 76973              36
# 76974              47
# 76975            3069
# 76976             378
# 76977              18
#
# [76978 rows x 7 columns]

# %%
x = y.groupby(['year', 'state_po', 'county_name'])['candidatevotes'].max()
x = pd.DataFrame(x)

fina_df = pd.merge(x, y, on = ['year', 'state_po', 'county_name'])

# %%
fina_df
# Out:
#        year state_po  county_name  candidatevotes_x        candidate  \
# 0      2000       AK   DISTRICT 1              4681          AL GORE
# 1      2000       AK   DISTRICT 1              4681   GEORGE W. BUSH
# 2      2000       AK   DISTRICT 1              4681            OTHER
# 3      2000       AK   DISTRICT 1              4681      RALPH NADER
# 4      2000       AK  DISTRICT 10              5673          AL GORE
# ...     ...      ...          ...               ...              ...
# 76973  2024       WY     WASHAKIE              3125            OTHER
# 76974  2024       WY       WESTON              3069     CHASE OLIVER
# 76975  2024       WY       WESTON              3069   DONALD J TRUMP
# 76976  2024       WY       WESTON              3069  KAMALA D HARRIS
# 76977  2024       WY       WESTON              3069            OTHER
#
#              party  candidatevotes_y result
# 0         DEMOCRAT              1284
# 1       REPUBLICAN              4681
# 2            OTHER               216
# 3            GREEN               475
# 4         DEMOCRAT              2194
# ...            ...               ...    ...
# 76973        OTHER                36
# 76974  LIBERTARIAN                47
# 76975   REPUBLICAN              3069
# 76976     DEMOCRAT               378
# 76977        OTHER                18
#
# [76978 rows x 8 columns]

# %%
fina_df['total_votes_of_winner'] = fina_df['candidatevotes_x']
fina_df['candidatevotes'] = fina_df['candidatevotes_y']

fina_df = fina_df.drop(columns = ['candidatevotes_y', 'candidatevotes_x'])

# %%
fina_df
# Out:
#        year state_po  county_name        candidate        party result  \
# 0      2000       AK   DISTRICT 1          AL GORE     DEMOCRAT
# 1      2000       AK   DISTRICT 1   GEORGE W. BUSH   REPUBLICAN
# 2      2000       AK   DISTRICT 1            OTHER        OTHER
# 3      2000       AK   DISTRICT 1      RALPH NADER        GREEN
# 4      2000       AK  DISTRICT 10          AL GORE     DEMOCRAT
# ...     ...      ...          ...              ...          ...    ...
# 76973  2024       WY     WASHAKIE            OTHER        OTHER
# 76974  2024       WY       WESTON     CHASE OLIVER  LIBERTARIAN
# 76975  2024       WY       WESTON   DONALD J TRUMP   REPUBLICAN
# 76976  2024       WY       WESTON  KAMALA D HARRIS     DEMOCRAT
# 76977  2024       WY       WESTON            OTHER        OTHER
#
#        total_votes_of_winner  candidatevotes
# 0                       4681            1284
# 1                       4681            4681
# 2                       4681             216
# 3                       4681             475
# 4                       5673            2194
# ...                      ...             ...
# 76973                   3125              36
# 76974                   3069              47
# 76975                   3069            3069
# 76976                   3069             378
# 76977                   3069              18
#
# [76978 rows x 8 columns]

# %%
fina_df['result'] = (fina_df['total_votes_of_winner'] == fina_df['candidatevotes']).astype(int)

# %%
final_df = fina_df.drop(columns = 'total_votes_of_winner')

# %%
final_df
# Out:
#        year state_po  county_name        candidate        party  result  \
# 0      2000       AK   DISTRICT 1          AL GORE     DEMOCRAT       0
# 1      2000       AK   DISTRICT 1   GEORGE W. BUSH   REPUBLICAN       1
# 2      2000       AK   DISTRICT 1            OTHER        OTHER       0
# 3      2000       AK   DISTRICT 1      RALPH NADER        GREEN       0
# 4      2000       AK  DISTRICT 10          AL GORE     DEMOCRAT       0
# ...     ...      ...          ...              ...          ...     ...
# 76973  2024       WY     WASHAKIE            OTHER        OTHER       0
# 76974  2024       WY       WESTON     CHASE OLIVER  LIBERTARIAN       0
# 76975  2024       WY       WESTON   DONALD J TRUMP   REPUBLICAN       1
# 76976  2024       WY       WESTON  KAMALA D HARRIS     DEMOCRAT       0
# 76977  2024       WY       WESTON            OTHER        OTHER       0
#
#        candidatevotes
# 0                1284
# 1                4681
# 2                 216
# 3                 475
# 4                2194
# ...               ...
# 76973              36
# 76974              47
# 76975            3069
# 76976             378
# 76977              18
#
# [76978 rows x 7 columns]

# %%
# def filter(df, year, state, county):
#     condition = df["year"] == year & df["state_po"] == state & df["county_name"] == county
#     new_df = df[condition]
#     return new_df

# filter(final_df, 2024, "WY", "WESTON")

# %% [markdown]
# Charts

# %%
states = final_df.groupby(['year', 'state_po', 'candidate', 'party'])['candidatevotes'].sum()
states = pd.DataFrame(states)
states = states.reset_index()

# %%
states
# Out:
#       year state_po        candidate        party  candidatevotes
# 0     2000       AK          AL GORE     DEMOCRAT           79004
# 1     2000       AK   GEORGE W. BUSH   REPUBLICAN          167398
# 2     2000       AK            OTHER        OTHER           10381
# 3     2000       AK      RALPH NADER        GREEN           28747
# 4     2000       AL          AL GORE     DEMOCRAT          695602
# ...    ...      ...              ...          ...             ...
# 1244  2024       WV            OTHER        OTHER           11478
# 1245  2024       WY     CHASE OLIVER  LIBERTARIAN            4193
# 1246  2024       WY   DONALD J TRUMP   REPUBLICAN          192633
# 1247  2024       WY  KAMALA D HARRIS     DEMOCRAT           69527
# 1248  2024       WY            OTHER        OTHER            2695
#
# [1249 rows x 5 columns]

# %%
years = final_df.groupby(['year', 'candidate', 'party'])['candidatevotes'].sum()
years = pd.DataFrame(years)
years = years.reset_index()

# %%
years
# Out:
#     year          candidate        party  candidatevotes
# 0   2000            AL GORE     DEMOCRAT        51001968
# 1   2000     GEORGE W. BUSH   REPUBLICAN        50457896
# 2   2000              OTHER        OTHER         1068557
# 3   2000        RALPH NADER        GREEN         2882954
# 4   2004     GEORGE W. BUSH   REPUBLICAN        61931981
# 5   2004         JOHN KERRY     DEMOCRAT        58899063
# 6   2004              OTHER        OTHER         1489505
# 7   2008       BARACK OBAMA     DEMOCRAT        69448278
# 8   2008        JOHN MCCAIN   REPUBLICAN        59928695
# 9   2008              OTHER        OTHER         1810364
# 10  2012       BARACK OBAMA     DEMOCRAT        65753019
# 11  2012        MITT ROMNEY   REPUBLICAN        60666387
# 12  2012              OTHER        OTHER         2629510
# 13  2016       DONALD TRUMP   REPUBLICAN        62979031
# 14  2016    HILLARY CLINTON     DEMOCRAT        65844241
# 15  2016              OTHER        OTHER         7674891
# 16  2020     DONALD J TRUMP   REPUBLICAN        74218999
# 17  2020       JO JORGENSEN  LIBERTARIAN         1810407
# 18  2020  JOSEPH R BIDEN JR     DEMOCRAT        81264648
# 19  2020              OTHER        GREEN          381070
# 20  2020              OTHER        OTHER          802586
# 21  2024       CHASE OLIVER  LIBERTARIAN          774086
# 22  2024     DONALD J TRUMP   REPUBLICAN        91435897
# 23  2024    KAMALA D HARRIS     DEMOCRAT        85882696
# 24  2024              OTHER        OTHER        21039775
# 25  2024          OVERVOTES        OTHER            9621
# 26  2024         UNDERVOTES        OTHER           37056

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
years_dict = {2000:{"candidates":[], "parties":[], "votes":[], "colors":[], "explode":[0.05, 0, 0, 0]},
              2004:{"candidates":[], "parties":[], "votes":[], "colors":[], "explode":[0.05, 0, 0]},
              2008:{"candidates":[], "parties":[], "votes":[], "colors":[], "explode":[0.05, 0, 0]},
              2012:{"candidates":[], "parties":[], "votes":[], "colors":[], "explode":[0.05, 0, 0]},
              2016:{"candidates":[], "parties":[], "votes":[], "colors":[], "explode":[0, 0.05, 0]},
              2020:{"candidates":[], "parties":[], "votes":[], "colors":[], "explode":[0, 0, 0.05, 0, 0]},
              2024:{"candidates":[], "parties":[], "votes":[], "colors":[], "explode":[0, 0.05, 0, 0]}}

for i, row in years.iterrows():
  for x in years_dict:
    if row[0] == x and (row[1] != "OVERVOTES" and row[1] != "UNDERVOTES"):
      years_dict[x]["candidates"].append(row[1])
      years_dict[x]["parties"].append(row[2])
      years_dict[x]["votes"].append(row[3])
      if row[2] == "DEMOCRAT":
        years_dict[x]["colors"].append("CornflowerBlue")
      elif row[2] == "REPUBLICAN":
        years_dict[x]["colors"].append("Crimson")
      elif row[2] == "GREEN":
        years_dict[x]["colors"].append("DarkGreen")
      elif row[2] == "LIBERTARIAN":
        years_dict[x]["colors"].append("DarkGray")
      else:
        years_dict[x]["colors"].append("BurlyWood")
# Out:
# C:\Users\CLT User\AppData\Local\Temp\ipykernel_19820\3817482385.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] == x and (row[1] != "OVERVOTES" and row[1] != "UNDERVOTES"):
# C:\Users\CLT User\AppData\Local\Temp\ipykernel_19820\3817482385.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   years_dict[x]["candidates"].append(row[1])
# C:\Users\CLT User\AppData\Local\Temp\ipykernel_19820\3817482385.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   years_dict[x]["parties"].append(row[2])
# C:\Users\CLT User\AppData\Local\Temp\ipykernel_19820\3817482385.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   years_dict[x]["votes"].append(row[3])
# C:\Users\CLT User\AppData\Local\Temp\ipykernel_19820\3817482385.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[2] == "DEMOCRAT":
# C:\Users\CLT User\AppData\Local\Temp\ipykernel_19820\3817482385.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif row[2] == "REPUBLICAN":
# C:\Users\CLT User\AppData\Local\Temp\ipykernel_19820\3817482385.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif row[2] == "GREEN":
# C:\Users\CLT User\AppData\Local\Temp\ipykernel_19820\3817482385.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif row[2] == "LIBERTARIAN":

# %%
years_dict
# Out:
# {2000: {'candidates': ['AL GORE', 'GEORGE W. BUSH', 'OTHER', 'RALPH NADER'],
#   'parties': ['DEMOCRAT', 'REPUBLICAN', 'OTHER', 'GREEN'],
#   'votes': [51001968, 50457896, 1068557, 2882954],
#   'colors': ['CornflowerBlue', 'Crimson', 'BurlyWood', 'DarkGreen'],
#   'explode': [0.05, 0, 0, 0]},
#  2004: {'candidates': ['GEORGE W. BUSH', 'JOHN KERRY', 'OTHER'],
#   'parties': ['REPUBLICAN', 'DEMOCRAT', 'OTHER'],
#   'votes': [61931981, 58899063, 1489505],
#   'colors': ['Crimson', 'CornflowerBlue', 'BurlyWood'],
#   'explode': [0.05, 0, 0]},
#  2008: {'candidates': ['BARACK OBAMA', 'JOHN MCCAIN', 'OTHER'],
#   'parties': ['DEMOCRAT', 'REPUBLICAN', 'OTHER'],
#   'votes': [69448278, 59928695, 1810364],
#   'colors': ['CornflowerBlue', 'Crimson', 'BurlyWood'],
#   'explode': [0.05, 0, 0]},
#  2012: {'candidates': ['BARACK OBAMA', 'MITT ROMNEY', 'OTHER'],
#   'parties': ['DEMOCRAT', 'REPUBLICAN', 'OTHER'],
#   'votes': [65753019, 60666387, 2629510],
#   'colors': ['CornflowerBlue', 'Crimson', 'BurlyWood'],
#   'explode': [0.05, 0, 0]},
#  2016: {'candidates': ['DONALD TRUMP', 'HILLARY CLINTON', 'OTHER'],
#   'parties': ['REPUBLICAN', 'DEMOCRAT', 'OTHER'],
#   'votes': [62979031, 65844241, 7674891],
#   'colors': ['Crimson', 'CornflowerBlue', 'BurlyWood'],
#   'explode': [0, 0.05, 0]},
#  2020: {'candidates': ['DONALD J TRUMP',
#    'JO JORGENSEN',
#    'JOSEPH R BIDEN JR',
#    'OTHER',
#    'OTHER'],
#   'parties': ['REPUBLICAN', 'LIBERTARIAN', 'DEMOCRAT', 'GREEN', 'OTHER'],
#   'votes': [74218999, 1810407, 81264648, 381070, 802586],
#   'colors': ['Crimson',
#    'DarkGray',
#    'CornflowerBlue',
#    'DarkGreen',
#    'BurlyWood'],
#   'explode': [0, 0, 0.05, 0, 0]},
#  2024: {'candidates': ['CHASE OLIVER',
#    'DONALD J TRUMP',
#    'KAMALA D HARRIS',
#    'OTHER'],
#   'parties': ['LIBERTARIAN', 'REPUBLICAN', 'DEMOCRAT', 'OTHER'],
#   'votes': [774086, 91435897, 85882696, 21039775],
#   'colors': ['DarkGray', 'Crimson', 'CornflowerBlue', 'BurlyWood'],
#   'explode': [0, 0.05, 0, 0]}}

# %%
for x in years_dict:
  fig, ax = plt.subplots()
  ax.set_title(f"{x} Election")
  ax.pie(years_dict[x]["votes"],
         labels= years_dict[x]["candidates"],
         colors=years_dict[x]["colors"],
         explode=years_dict[x]["explode"],
         autopct='%1.1f%%')
  # ax.legend(years_dict[x]["parties"],
  #           title = "Parties",
  #           loc="center left",
  #           bbox_to_anchor=(1.5, 0, 0.5, 1))
  ax.legend(years_dict[x]["votes"],
            title="Number of Votes",
            loc="center left",
            bbox_to_anchor=(1.2, 0, 0.5, 1))
  plt.show()
